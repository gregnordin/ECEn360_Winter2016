# %%
# !which python
# Out:
# /Users/nordin/anaconda/envs/py35bokeh/bin/python

# %%
# !python --version
# Out:
# Python 3.5.1 :: Anaconda 2.4.1 (x86_64)

# %%
# !git branch
# Out:
# * dev
#   master

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook, curdoc, vplot,  hplot

output_notebook()
# Out:
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev5.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev5.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev5.min.css" type="text/css" />
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev5.min.css" type="text/css" />
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
x = np.linspace(0, 4*np.pi, 100)
y = np.sin(x)

p = figure()
r1 = p.line([0, 4*np.pi], [-1, 1], color="firebrick")
r2 = p.line(x, y, color="navy", line_width=4)

# %% [markdown]
# Typing `r1.` and then `shift-Tab` three times I get the following information:
#
#     Type:        GlyphRenderer
#     String form: GlyphRenderer, ViewModel:GlyphRenderer, ref _id: aba6ffb6-455d-4dba-9790-16d0d608e3b5
#     File:        ~/anaconda/envs/py35/lib/python3.5/site-packages/bokeh/models/renderers.py
#     Docstring:
#
# Go to the renderers.py file and look at the code for `GlyphRenderer` to find its attributes.

# %% [markdown]
# Now do the same with `r1.glyph.` to find its properties by looking in the file referenced below:
#
#     Type:        Line
#     String form: Line, ViewModel:Line, ref _id: 88845913-46b5-427b-9381-e373ed0c6080
#     File:        ~/anaconda/envs/py35/lib/python3.5/site-packages/bokeh/models/glyphs.py
#     Docstring:
#     Render a single line.
#
#     .. note::
#         The ``Line`` glyph is different from most other glyphs in that
#         the vector of values only produces one glyph on the Plot.
#
# There's not much in the definition of the `Line` class, but it's immediate parent does have one (and only one) attribute that is interesting: `visible`. Let' try it out.

# %%
show(p)
# Out:
#     <script type="text/javascript">
#         Bokeh.$(function() {
#
#           var websocket_url = null;
#
#         var docs_json = {"5bc71622-96e1-4d7b-b3fc-988792a84b33": {"roots": {"references": [{"attributes": {"dimensions": ["width", "height"], "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": []}, "type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"attributes": {"mantissas": [1, 2, 5], "name": null, "desired_num_ticks": 6, "min_interval": 0.0, "max_interval": null, "tags": [], "num_minor_ticks": 5, "base": 10.0}, "type": "BasicTicker", "id": "062f7245-a858-4514-8e39-259722c11481"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": [], "help_tooltip": "Click the question mark to learn more about Bokeh plot tools.", "redirect": "http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html"}, "type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}, {"attributes": {"major_tick_line_dash_offset": 0, "formatter": {"type": "BasicTickFormatter", "id": "2fcd4e11-1b9c-4345-9794-2f06240441e7"}, "major_tick_line_join": "miter", "tags": [], "axis_label_text_alpha": {"value": 1.0}, "axis_label_standoff": 5, "minor_tick_line_join": "miter", "axis_label": "", "major_label_text_alpha": {"value": 1.0}, "axis_line_dash": [], "level": "overlay", "axis_label_text_font_size": {"value": "16pt"}, "axis_line_dash_offset": 0, "axis_label_text_color": {"value": "#444444"}, "location": "auto", "minor_tick_line_dash_offset": 0, "minor_tick_in": 0, "bounds": "auto", "x_range_name": "default", "axis_line_color": {"value": "black"}, "major_tick_line_dash": [], "major_tick_out": 6, "major_label_text_align": "center", "minor_tick_line_alpha": {"value": 1.0}, "major_label_text_baseline": "alphabetic", "major_tick_in": 2, "major_label_standoff": 5, "minor_tick_out": 4, "major_label_text_color": {"value": "#444444"}, "major_label_text_font": "helvetica", "ticker": {"type": "BasicTicker", "id": "2b8a744b-26d5-4ada-8a0f-9654a3f9740c"}, "major_tick_line_alpha": {"value": 1.0}, "axis_label_text_font_style": "normal", "minor_tick_line_dash": [], "major_tick_line_color": {"value": "black"}, "major_label_orientation": "horizontal", "major_label_text_font_style": "normal", "axis_line_width": {"value": 1}, "major_label_text_font_size": {"value": "10pt"}, "major_tick_line_cap": "butt", "axis_label_text_font": "helvetica", "minor_tick_line_color": {"value": "black"}, "name": null, "major_tick_line_width": {"value": 1}, "axis_label_text_baseline": "alphabetic", "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "minor_tick_line_cap": "butt", "axis_line_alpha": {"value": 1.0}, "minor_tick_line_width": {"value": 1}, "axis_label_text_align": "center", "axis_line_cap": "butt", "y_range_name": "default", "axis_line_join": "miter", "visible": true}, "type": "LinearAxis", "id": "7e6f5667-8bb1-4b95-82d3-60af2e996d12"}, {"attributes": {"disabled": false, "toolbar_location": "above", "title_text_font_size": {"value": "20pt"}, "y_mapper_type": "auto", "border_fill_alpha": {"value": 1.0}, "tools": [{"type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"type": "WheelZoomTool", "id": "5b378d66-de14-477e-9e7e-64a4e89bf610"}, {"type": "BoxZoomTool", "id": "5201e18b-12b2-4a6c-b644-3a5bcfc54b81"}, {"type": "PreviewSaveTool", "id": "136cb3b6-a3f9-4b91-af25-8866aa94da8f"}, {"type": "ResizeTool", "id": "d4675fae-0f9c-45e4-84a1-61b9f427b7bc"}, {"type": "ResetTool", "id": "b3426492-9732-46b0-ae0e-13088871cd6a"}, {"type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}], "outline_line_color": {"value": "#aaaaaa"}, "webgl": false, "v_symmetry": false, "title_text_color": {"value": "#444444"}, "tool_events": {"type": "ToolEvents", "id": "6cc892db-672d-4e70-8825-da9f328e2225"}, "outline_line_alpha": {"value": 1.0}, "title_text_alpha": {"value": 1.0}, "outline_line_width": {"value": 1}, "extra_y_ranges": {}, "background_fill_alpha": {"value": 1.0}, "responsive": false, ...

# %%
r1.glyph.visible = False
show(p)
# Out:
#     <script type="text/javascript">
#         Bokeh.$(function() {
#
#           var websocket_url = null;
#
#         var docs_json = {"36e604fb-db5c-4a26-9840-750ff7656729": {"roots": {"references": [{"attributes": {"dimensions": ["width", "height"], "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": []}, "type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"attributes": {"mantissas": [1, 2, 5], "name": null, "desired_num_ticks": 6, "min_interval": 0.0, "max_interval": null, "tags": [], "num_minor_ticks": 5, "base": 10.0}, "type": "BasicTicker", "id": "062f7245-a858-4514-8e39-259722c11481"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": [], "help_tooltip": "Click the question mark to learn more about Bokeh plot tools.", "redirect": "http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html"}, "type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}, {"attributes": {"major_tick_line_dash_offset": 0, "formatter": {"type": "BasicTickFormatter", "id": "2fcd4e11-1b9c-4345-9794-2f06240441e7"}, "major_tick_line_join": "miter", "tags": [], "axis_label_text_alpha": {"value": 1.0}, "axis_label_standoff": 5, "minor_tick_line_join": "miter", "axis_label": "", "major_label_text_alpha": {"value": 1.0}, "axis_line_dash": [], "level": "overlay", "axis_label_text_font_size": {"value": "16pt"}, "axis_line_dash_offset": 0, "axis_label_text_color": {"value": "#444444"}, "location": "auto", "minor_tick_line_dash_offset": 0, "minor_tick_in": 0, "bounds": "auto", "x_range_name": "default", "axis_line_color": {"value": "black"}, "major_tick_line_dash": [], "major_tick_out": 6, "major_label_text_align": "center", "minor_tick_line_alpha": {"value": 1.0}, "major_label_text_baseline": "alphabetic", "major_tick_in": 2, "major_label_standoff": 5, "minor_tick_out": 4, "major_label_text_color": {"value": "#444444"}, "major_label_text_font": "helvetica", "ticker": {"type": "BasicTicker", "id": "2b8a744b-26d5-4ada-8a0f-9654a3f9740c"}, "major_tick_line_alpha": {"value": 1.0}, "axis_label_text_font_style": "normal", "minor_tick_line_dash": [], "major_tick_line_color": {"value": "black"}, "major_label_orientation": "horizontal", "major_label_text_font_style": "normal", "axis_line_width": {"value": 1}, "major_label_text_font_size": {"value": "10pt"}, "major_tick_line_cap": "butt", "axis_label_text_font": "helvetica", "minor_tick_line_color": {"value": "black"}, "name": null, "major_tick_line_width": {"value": 1}, "axis_label_text_baseline": "alphabetic", "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "minor_tick_line_cap": "butt", "axis_line_alpha": {"value": 1.0}, "minor_tick_line_width": {"value": 1}, "axis_label_text_align": "center", "axis_line_cap": "butt", "y_range_name": "default", "axis_line_join": "miter", "visible": true}, "type": "LinearAxis", "id": "7e6f5667-8bb1-4b95-82d3-60af2e996d12"}, {"attributes": {"disabled": false, "toolbar_location": "above", "title_text_font_size": {"value": "20pt"}, "y_mapper_type": "auto", "border_fill_alpha": {"value": 1.0}, "tools": [{"type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"type": "WheelZoomTool", "id": "5b378d66-de14-477e-9e7e-64a4e89bf610"}, {"type": "BoxZoomTool", "id": "5201e18b-12b2-4a6c-b644-3a5bcfc54b81"}, {"type": "PreviewSaveTool", "id": "136cb3b6-a3f9-4b91-af25-8866aa94da8f"}, {"type": "ResizeTool", "id": "d4675fae-0f9c-45e4-84a1-61b9f427b7bc"}, {"type": "ResetTool", "id": "b3426492-9732-46b0-ae0e-13088871cd6a"}, {"type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}], "outline_line_color": {"value": "#aaaaaa"}, "webgl": false, "v_symmetry": false, "title_text_color": {"value": "#444444"}, "tool_events": {"type": "ToolEvents", "id": "6cc892db-672d-4e70-8825-da9f328e2225"}, "outline_line_alpha": {"value": 1.0}, "title_text_alpha": {"value": 1.0}, "outline_line_width": {"value": 1}, "extra_y_ranges": {}, "background_fill_alpha": {"value": 1.0}, "responsive": false, ...

# %%
r1.glyph.visible = True
r2.glyph.visible = False
show(p)
# Out:
#     <script type="text/javascript">
#         Bokeh.$(function() {
#
#           var websocket_url = null;
#
#         var docs_json = {"7e5f6a0c-86f9-4c8c-b308-2390cc699a15": {"roots": {"references": [{"attributes": {"dimensions": ["width", "height"], "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": []}, "type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"attributes": {"mantissas": [1, 2, 5], "name": null, "desired_num_ticks": 6, "min_interval": 0.0, "max_interval": null, "tags": [], "num_minor_ticks": 5, "base": 10.0}, "type": "BasicTicker", "id": "062f7245-a858-4514-8e39-259722c11481"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": [], "help_tooltip": "Click the question mark to learn more about Bokeh plot tools.", "redirect": "http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html"}, "type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}, {"attributes": {"major_tick_line_dash_offset": 0, "formatter": {"type": "BasicTickFormatter", "id": "2fcd4e11-1b9c-4345-9794-2f06240441e7"}, "major_tick_line_join": "miter", "tags": [], "axis_label_text_alpha": {"value": 1.0}, "axis_label_standoff": 5, "minor_tick_line_join": "miter", "axis_label": "", "major_label_text_alpha": {"value": 1.0}, "axis_line_dash": [], "level": "overlay", "axis_label_text_font_size": {"value": "16pt"}, "axis_line_dash_offset": 0, "axis_label_text_color": {"value": "#444444"}, "location": "auto", "minor_tick_line_dash_offset": 0, "minor_tick_in": 0, "bounds": "auto", "x_range_name": "default", "axis_line_color": {"value": "black"}, "major_tick_line_dash": [], "major_tick_out": 6, "major_label_text_align": "center", "minor_tick_line_alpha": {"value": 1.0}, "major_label_text_baseline": "alphabetic", "major_tick_in": 2, "major_label_standoff": 5, "minor_tick_out": 4, "major_label_text_color": {"value": "#444444"}, "major_label_text_font": "helvetica", "ticker": {"type": "BasicTicker", "id": "2b8a744b-26d5-4ada-8a0f-9654a3f9740c"}, "major_tick_line_alpha": {"value": 1.0}, "axis_label_text_font_style": "normal", "minor_tick_line_dash": [], "major_tick_line_color": {"value": "black"}, "major_label_orientation": "horizontal", "major_label_text_font_style": "normal", "axis_line_width": {"value": 1}, "major_label_text_font_size": {"value": "10pt"}, "major_tick_line_cap": "butt", "axis_label_text_font": "helvetica", "minor_tick_line_color": {"value": "black"}, "name": null, "major_tick_line_width": {"value": 1}, "axis_label_text_baseline": "alphabetic", "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "minor_tick_line_cap": "butt", "axis_line_alpha": {"value": 1.0}, "minor_tick_line_width": {"value": 1}, "axis_label_text_align": "center", "axis_line_cap": "butt", "y_range_name": "default", "axis_line_join": "miter", "visible": true}, "type": "LinearAxis", "id": "7e6f5667-8bb1-4b95-82d3-60af2e996d12"}, {"attributes": {"disabled": false, "toolbar_location": "above", "title_text_font_size": {"value": "20pt"}, "y_mapper_type": "auto", "border_fill_alpha": {"value": 1.0}, "tools": [{"type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"type": "WheelZoomTool", "id": "5b378d66-de14-477e-9e7e-64a4e89bf610"}, {"type": "BoxZoomTool", "id": "5201e18b-12b2-4a6c-b644-3a5bcfc54b81"}, {"type": "PreviewSaveTool", "id": "136cb3b6-a3f9-4b91-af25-8866aa94da8f"}, {"type": "ResizeTool", "id": "d4675fae-0f9c-45e4-84a1-61b9f427b7bc"}, {"type": "ResetTool", "id": "b3426492-9732-46b0-ae0e-13088871cd6a"}, {"type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}], "outline_line_color": {"value": "#aaaaaa"}, "webgl": false, "v_symmetry": false, "title_text_color": {"value": "#444444"}, "tool_events": {"type": "ToolEvents", "id": "6cc892db-672d-4e70-8825-da9f328e2225"}, "outline_line_alpha": {"value": 1.0}, "title_text_alpha": {"value": 1.0}, "outline_line_width": {"value": 1}, "extra_y_ranges": {}, "background_fill_alpha": {"value": 1.0}, "responsive": false, ...

# %%
r2.glyph.visible = True
r2.glyph.trigger('visible',False,True)

# %%
show(p)
# Out:
#     <script type="text/javascript">
#         Bokeh.$(function() {
#
#           var websocket_url = null;
#
#         var docs_json = {"579d412b-f2bb-4904-8a7d-faf8b9b44351": {"roots": {"references": [{"attributes": {"dimensions": ["width", "height"], "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": []}, "type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"attributes": {"mantissas": [1, 2, 5], "name": null, "desired_num_ticks": 6, "min_interval": 0.0, "max_interval": null, "tags": [], "num_minor_ticks": 5, "base": 10.0}, "type": "BasicTicker", "id": "062f7245-a858-4514-8e39-259722c11481"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "name": null, "tags": [], "help_tooltip": "Click the question mark to learn more about Bokeh plot tools.", "redirect": "http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html"}, "type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}, {"attributes": {"major_tick_line_dash_offset": 0, "formatter": {"type": "BasicTickFormatter", "id": "2fcd4e11-1b9c-4345-9794-2f06240441e7"}, "major_tick_line_join": "miter", "tags": [], "axis_label_text_alpha": {"value": 1.0}, "axis_label_standoff": 5, "minor_tick_line_join": "miter", "axis_label": "", "major_label_text_alpha": {"value": 1.0}, "axis_line_dash": [], "level": "overlay", "axis_label_text_font_size": {"value": "16pt"}, "axis_line_dash_offset": 0, "axis_label_text_color": {"value": "#444444"}, "location": "auto", "minor_tick_line_dash_offset": 0, "minor_tick_in": 0, "bounds": "auto", "x_range_name": "default", "axis_line_color": {"value": "black"}, "major_tick_line_dash": [], "major_tick_out": 6, "major_label_text_align": "center", "minor_tick_line_alpha": {"value": 1.0}, "major_label_text_baseline": "alphabetic", "major_tick_in": 2, "major_label_standoff": 5, "minor_tick_out": 4, "major_label_text_color": {"value": "#444444"}, "major_label_text_font": "helvetica", "ticker": {"type": "BasicTicker", "id": "2b8a744b-26d5-4ada-8a0f-9654a3f9740c"}, "major_tick_line_alpha": {"value": 1.0}, "axis_label_text_font_style": "normal", "minor_tick_line_dash": [], "major_tick_line_color": {"value": "black"}, "major_label_orientation": "horizontal", "major_label_text_font_style": "normal", "axis_line_width": {"value": 1}, "major_label_text_font_size": {"value": "10pt"}, "major_tick_line_cap": "butt", "axis_label_text_font": "helvetica", "minor_tick_line_color": {"value": "black"}, "name": null, "major_tick_line_width": {"value": 1}, "axis_label_text_baseline": "alphabetic", "plot": {"subtype": "Figure", "type": "Plot", "id": "57c0759f-7439-415e-bb1c-777262b27bcf"}, "minor_tick_line_cap": "butt", "axis_line_alpha": {"value": 1.0}, "minor_tick_line_width": {"value": 1}, "axis_label_text_align": "center", "axis_line_cap": "butt", "y_range_name": "default", "axis_line_join": "miter", "visible": true}, "type": "LinearAxis", "id": "7e6f5667-8bb1-4b95-82d3-60af2e996d12"}, {"attributes": {"disabled": false, "toolbar_location": "above", "title_text_font_size": {"value": "20pt"}, "y_mapper_type": "auto", "border_fill_alpha": {"value": 1.0}, "tools": [{"type": "PanTool", "id": "327e8be7-3e17-40d7-94a0-4f44478c9ee3"}, {"type": "WheelZoomTool", "id": "5b378d66-de14-477e-9e7e-64a4e89bf610"}, {"type": "BoxZoomTool", "id": "5201e18b-12b2-4a6c-b644-3a5bcfc54b81"}, {"type": "PreviewSaveTool", "id": "136cb3b6-a3f9-4b91-af25-8866aa94da8f"}, {"type": "ResizeTool", "id": "d4675fae-0f9c-45e4-84a1-61b9f427b7bc"}, {"type": "ResetTool", "id": "b3426492-9732-46b0-ae0e-13088871cd6a"}, {"type": "HelpTool", "id": "653dce15-6b4b-4bb8-be3d-187e6e2d1660"}], "outline_line_color": {"value": "#aaaaaa"}, "webgl": false, "v_symmetry": false, "title_text_color": {"value": "#444444"}, "tool_events": {"type": "ToolEvents", "id": "6cc892db-672d-4e70-8825-da9f328e2225"}, "outline_line_alpha": {"value": 1.0}, "title_text_alpha": {"value": 1.0}, "outline_line_width": {"value": 1}, "extra_y_ranges": {}, "background_fill_alpha": {"value": 1.0}, "responsive": false, ...
